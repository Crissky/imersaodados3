# %% [markdown]
# <a href="https://colab.research.google.com/github/Crissky/imersaodados3/blob/main/Aula4/4_Merge_de_dados_e_an%C3%A1lise_de_resultados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [\#4 Merge de dados e análise de resultados](https://www.alura.com.br/imersao-dados/aula04-merge-dados-analise-resultados)
#
# **Links**:
#  - [Todas as informações sobre o projeto final](https://github.com/alura-cursos/imersao-dados-desafio-final)
#  - [Documentação da função merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)
#  - [Spurious Correlations](https://www.tylervigen.com/spurious-correlations)
#  - [Laboratory innovation science at Harvard](https://lish.harvard.edu/)
#  - Competição no [Kaggle](https://www.kaggle.com/c/lish-moa)
#
# **Artigos**:
#  - [Histogramas](https://www.alura.com.br/artigos/o-que-e-um-histograma?utm_source=gnarus&utm_medium=timeline)
#  - [Describe](https://www.alura.com.br/artigos/ampliando-a-analise-com-describe)
#  - [Boxplot](https://www.alura.com.br/artigos/melhorando-a-analise-com-o-boxplot)

# %%
from IPython.display import HTML

# %% [markdown]
# ## Aula 4

# %%
HTML('<iframe width="800" height="450" src="https://www.youtube.com/embed/meOsw7STwus" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="800" height="450" src="https://www.youtube.com/embed/meOsw7STwus" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Baixando Base de Dados

# %%
# !rm -r imersaodados3/
# !git clone https://github.com/alura-cursos/imersaodados3
# Out:
# Cloning into 'imersaodados3'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 342 (delta 97), reused 89 (delta 39), pack-reused 194
# Receiving objects: 100% (342/342), 106.28 MiB | 23.05 MiB/s, done.
# Resolving deltas: 100% (203/203), done.

# %% [markdown]
# ## Importando Bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (10,8) # Define o tamanho dos gráficos.

# %% [markdown]
# ## Lendo CSV zipado e exibindo dados

# %%
df = pd.read_csv("imersaodados3/dados/dados_experimentos.zip", compression='zip')

df.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Lendo CSV dos resultados

# %%
df_result = pd.read_csv('imersaodados3/dados/dados_resultados.csv')

df_result.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# ## Exibindo informações do CSV

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
df_result['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
df_result['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Somando Colunas

# %%
contagem_moa = df_result.drop('id', axis=1).sum().sort_values(ascending=False)

contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = df_result.select_dtypes('int64').sum().sort_values(ascending=False)

contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# ## Somando Linhas

# %%
df_result.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# ## Criado Coluna

# %%
df_result['n_moa'] = df_result.drop('id', axis=1).sum(axis=1)

df_result.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
df_result['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
df_result['ativo_moa'] = df_result['n_moa'] != 0

df_result.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# ## Unindo Dataframes (Merge)

# %%
df_combo = pd.merge(df, df_result[['id','n_moa', 'ativo_moa']], on='id')

df_combo.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# ## Contando quantos tratamentos ativaram o "mecanismo de ação" (moa)

# %%
df_combo.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
df_combo.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# ## Adicionando coluna "eh_controle"

# %%
df_combo['eh_controle'] = df_combo['tratamento'] == "com_controle"

df_combo.tail()
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [5 rows x 880 columns]

# %% [markdown]
# ## Adicionando Colunas 24, 48, 72

# %%
pd.get_dummies(df_combo['tempo'])
# Out:
#        24  48  72
# 0       1   0   0
# 1       0   0   1
# 2       0   1   0
# 3       0   1   0
# 4       0   0   1
# ...    ..  ..  ..
# 23809   1   0   0
# 23810   1   0   0
# 23811   0   1   0
# 23812   1   0   0
# 23813   0   0   1
#
# [23814 rows x 3 columns]

# %%
df_combo = pd.concat([df_combo, pd.get_dummies(df_combo['tempo'])], axis=1)

df_combo
# Out:
#                  id    tratamento  tempo dose  ... eh_controle  24  48  72
# 0      id_000644bb2     com_droga     24   D1  ...       False   1   0   0
# 1      id_000779bfc     com_droga     72   D1  ...       False   0   0   1
# 2      id_000a6266a     com_droga     48   D1  ...       False   0   1   0
# 3      id_0015fd391     com_droga     48   D1  ...       False   0   1   0
# 4      id_001626bd3     com_droga     72   D2  ...       False   0   0   1
# ...             ...           ...    ...  ...  ...         ...  ..  ..  ..
# 23809  id_fffb1ceed     com_droga     24   D2  ...       False   1   0   0
# 23810  id_fffb70c0c     com_droga     24   D2  ...       False   1   0   0
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True   0   1   0
# 23812  id_fffcb9e7c     com_droga     24   D1  ...       False   1   0   0
# 23813  id_ffffdd77b     com_droga     72   D1  ...       False   0   0   1
#
# [23814 rows x 883 columns]

# %% [markdown]
# ## BoxPlot das principais drogas

# %%
principais_compostos = df_combo['droga'].value_counts().index[:11]
principais_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee',
#        'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d', '67c879e79',
#        '83a9ea167'],
#       dtype='object')

# %%
sns.boxplot(data=df_combo.query('droga in @principais_compostos'), x='droga', y='g-0')

# %%
sns.boxplot(data=df_combo.query('droga in @principais_compostos'), x='droga', y='g-0', hue='ativo_moa')
